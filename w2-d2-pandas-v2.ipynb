# %%
import pandas as pd

poke = pd.read_csv("data/pokemon.csv")

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
poke["ratio"] = poke["Attack"] / poke["Defense"]

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
sorted_by_ratio = poke[["Name","ratio"]].sort_values(by="ratio",ascending=False)
sorted_by_ratio
# Out:
#                       Name     ratio
# 429     DeoxysAttack Forme  9.000000
# 347               Carvanha  4.500000
# 19   BeedrillMega Beedrill  3.750000
# 453               Cranidos  3.125000
# 348               Sharpedo  3.000000
# ..                     ...       ...
# 616     DarmanitanZen Mode  0.285714
# 103                   Onix  0.281250
# 484                Bronzor  0.279070
# 139               Magikarp  0.181818
# 230                Shuckle  0.043478
#
# [800 rows x 2 columns]

# %%
sorted_by_ratio.loc[0]
# Out:
# Name     Bulbasaur
# ratio            1
# Name: 0, dtype: object

# %%
q = sorted_by_ratio.reset_index()
display(q)
q[q["index"]==0]
# Out:
#      index                   Name     ratio
# 0      429     DeoxysAttack Forme  9.000000
# 1      347               Carvanha  4.500000
# 2       19  BeedrillMega Beedrill  3.750000
# 3      453               Cranidos  3.125000
# 4      348               Sharpedo  3.000000
# ..     ...                    ...       ...
# 795    616     DarmanitanZen Mode  0.285714
# 796    103                   Onix  0.281250
# 797    484                Bronzor  0.279070
# 798    139               Magikarp  0.181818
# 799    230                Shuckle  0.043478
#
# [800 rows x 3 columns]
#      index       Name  ratio
# 473      0  Bulbasaur    1.0

# %%
poke["Name"].sort_values()
# Out:
# 510                  Abomasnow
# 511    AbomasnowMega Abomasnow
# 68                        Abra
# 392                      Absol
# 393            AbsolMega Absol
#                 ...
# 632                    Zoroark
# 631                      Zorua
# 46                       Zubat
# 695                   Zweilous
# 794           Zygarde50% Forme
# Name: Name, Length: 800, dtype: object

# %%
poke.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation       ratio
# count  800.000000  800.000000   800.00000  800.000000
# mean    71.902500   68.277500     3.32375    1.164547
# std     27.828916   29.060474     1.66129    0.552604
# min     20.000000    5.000000     1.00000    0.043478
# ...

# %%
poke.describe().T["50%"].Attack
# Out:
# 75.0

# %%
poke.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation       ratio
# count  800.000000  800.000000   800.00000  800.000000
# mean    71.902500   68.277500     3.32375    1.164547
# std     27.828916   29.060474     1.66129    0.552604
# min     20.000000    5.000000     1.00000    0.043478
# ...

# %%
poke.describe().Defense["std"]
# Out:
# 31.183500559332934

# %%
#np.percent(poke["HP"],70)

# %%
# %matplotlib inline
q = poke[["Name","Attack"]].sort_values(by="Attack", ascending=False)
display(q)
q = q.head(10).set_index("Name")
display(q)
q.plot.bar()
# Out:
#                         Name  Attack
# 163      MewtwoMega Mewtwo X     190
# 232  HeracrossMega Heracross     185
# 424    GroudonPrimal Groudon     180
# 426    RayquazaMega Rayquaza     180
# 429       DeoxysAttack Forme     180
# ..                       ...     ...
# 139                 Magikarp      10
# 261                  Blissey      10
# 230                  Shuckle      10
# 121                  Chansey       5
# 488                  Happiny       5
#
# [800 rows x 2 columns]
#                          Attack
# Name
# MewtwoMega Mewtwo X         190
# HeracrossMega Heracross     185
# GroudonPrimal Groudon       180
# RayquazaMega Rayquaza       180
# DeoxysAttack Forme          180
# KyuremBlack Kyurem          170
# GarchompMega Garchomp       170
# GalladeMega Gallade         165
# BanetteMega Banette         165
# Rampardos                   165
