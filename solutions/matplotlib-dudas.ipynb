# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.random.random((10,2))
X
# Out:
# array([[0.1411239 , 0.99958946],
#        [0.25961469, 0.82611514],
#        [0.91377673, 0.60224516],
#        [0.78566953, 0.3614685 ],
#        [0.64525579, 0.25490112],
#        [0.65896078, 0.01752232],
#        [0.74368789, 0.04813105],
#        [0.54763292, 0.26097276],
#        [0.67815656, 0.89051648],
#        [0.12148731, 0.51197989]])

# %%
plt.plot(X,'o-')

# %%
plt.plot(X.T,'o-')

# %%
print(X[:,0])
print(X[:,1])
# Out:
# [0.1411239  0.25961469 0.91377673 0.78566953 0.64525579 0.65896078
#  0.74368789 0.54763292 0.67815656 0.12148731]
# [0.99958946 0.82611514 0.60224516 0.3614685  0.25490112 0.01752232
#  0.04813105 0.26097276 0.89051648 0.51197989]

# %%
plt.plot(X[:,0],X[:,1],'o-')

# %%
import pandas as pd


df = pd.DataFrame(np.random.random((10,2)),columns=["muertos","año"])
df
# Out:
#     muertos       año
# 0  0.459887  0.911140
# 1  0.529336  0.499438
# 2  0.125043  0.308091
# 3  0.927371  0.180694
# 4  0.143975  0.812178
# 5  0.962281  0.489339
# 6  0.830495  0.078249
# 7  0.264602  0.122976
# 8  0.301063  0.746838
# 9  0.174941  0.831210

# %%
# Coordenada X = Muertos, Coordenada Y = año

plt.plot(df["muertos"],df["año"],'o')
plt.xlabel("muertos")
plt.ylabel("año")
# Out:
# Text(0, 0.5, 'año')
